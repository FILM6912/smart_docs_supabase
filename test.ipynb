# %%
import base64
from PIL import Image
import io
image_bytes = base64.b64decode(image_bytes )

# 2) bytes → PIL Image
img = Image.open(io.BytesIO(image_bytes))

# Optional: convert if needed
img = img.convert("RGB")
img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 from PIL import Image
#       3 import io
# ----> 4 image_bytes = base64.b64decode(image_bytes )
#       6 # 2) bytes → PIL Image
#       7 img = Image.open(io.BytesIO(image_bytes))
#
# NameError: name 'image_bytes' is not defined

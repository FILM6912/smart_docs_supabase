# %%
# import os
# from supabase import create_client, Client

# url: str = os.environ.get("SUPABASE_URL")
# key: str = os.environ.get("ANON_KEY")
# supabase: Client = create_client(url, key)


# # Mock data for testing
# doc_id = 24
# update_data = {
#     "title": "Updated Document",
#     "category_name": "Sample Category",
#     "data": "This is the updated content.",
#     "last_updated": "2024-01-01T00:00:00.000Z",
#     "updated_by": "John Doe",
#     "updated_by_id": 123
# }

# supabase.schema("smart_documents").table("documents").update(update_data).eq("id", doc_id).execute().data

# %%
import requests
data = {
    "email": "filmmagic69@gmail.com",
    "password": "film"
}
headers = {
    "accept": "application/json",
    "Content-Type": "application/x-www-form-urlencoded"
}
response = requests.post("http://localhost:8000/auth/login", data=data, headers=headers)
response.json()
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJmaWxtbWFnaWM2OUBnbWFpbC5jb20iLCJpZCI6IjNmNmJmZDg0LTE3N2UtNDY3Yy1hMjhhLTU1N2RmODNiZWE5NiIsInJvbGUiOiJzdXBlcmFkbWluIiwiZnVsbF9uYW1lIjoiZmYiLCJleHAiOjE3NjM0OTc2Mjd9.JD5aT98dh1XZq8Pu3B4H0LiYQ4lUAKQN6QF5XuUTS5A',
#  'token_type': 'bearer',
#  'id': '3f6bfd84-177e-467c-a28a-557df83bea96',
#  'email': 'filmmagic69@gmail.com',
#  'full_name': 'ff',
#  'role': 'superadmin'}

# %%
from httpx import head


data={
  "docData": {
    "title": "Test",
    "content": "asdasda\n![รูปภาพ](blob:http://localhost:5173/fd735971-bd60-4232-b96a-37d9d5354a4c)\n\nasdasdasd\n![รูปภาพ](blob:http://localhost:5173/0463fecd-5c82-455e-8963-0c8bae3d3034)\n\n```js\nconsole.log(\"kuay\")\n```",
    "category": "test"
  },
  "imgRef": [
    {
      "refer": "![รูปภาพ](blob:http://localhost:5173/fd735971-bd60-4232-b96a-37d9d5354a4c)",
      "imgByte": "..."
    },
    {
      "refer": "![รูปภาพ](blob:http://localhost:5173/0463fecd-5c82-455e-8963-0c8bae3d3034)",
      "imgByte": "..."
    }
  ]
}

headers={
    "Authorization": "Bearer "+response.json()["access_token"]
}

response1=requests.post("http://localhost:8000/documents/",json=data,headers=headers)
response1.json()
# Out:
# {'title': 'Test',
#  'category_name': 'test',
#  'data': 'asdasda\n![รูปภาพ](http://192.168.195.200:8010/storage/v1/object/public/documents_images/26/94790e3f-ed81-4f91-8917-d8a053c82642_image_0.png)\n\nasdasdasd\n![รูปภาพ](http://192.168.195.200:8010/storage/v1/object/public/documents_images/26/fab42b69-f80a-4e47-ba73-208c0b40902c_image_1.png)\n\n```js\nconsole.log("kuay")\n```',
#  'id': 26,
#  'created_at': '2025-11-18T12:27:10.731584Z',
#  'last_updated': '2025-11-18T12:27:10.731584',
#  'updated_by': None,
#  'created_by': 'ff',
#  'created_by_id': '3f6bfd84-177e-467c-a28a-557df83bea96',
#  'updated_by_id': None}

# %%
from httpx import head


data={
  "docData": {
    "title": "Test",
    "content": "iiiii\n![รูปภาพ](blob:http://localhost:5173/fd735971-bd60-4232-b96a-37d9d5354a4c)\n\nasdasdasd\n![รูปภาพ](blob:http://localhost:5173/0463fecd-5c82-455e-8963-0c8bae3d3034)\n\n```js\nconsole.log(\"kuay\")\n```",
    "category": "test"
  },
  "imgRef": [
    {
      "refer": "![รูปภาพ](blob:http://localhost:5173/fd735971-bd60-4232-b96a-37d9d5354a4c)",
      "imgByte": "..."
    },
    {
      "refer": "![รูปภาพ](blob:http://localhost:5173/0463fecd-5c82-455e-8963-0c8bae3d3034)",
      "imgByte": "..."
    }
  ]
}

headers={
    "Authorization": "Bearer "+response.json()["access_token"]
}

response1=requests.put("http://localhost:8000/documents/26",json=data,headers=headers)
response1.json()
# Out:
# {'title': 'Test',
#  'category_name': 'test',
#  'data': 'iiiii\n![รูปภาพ](http://192.168.195.200:8010/storage/v1/object/public/documents_images/26/11a884cd-7673-4f81-a3dc-946fce4a11e2_image_0.png)\n\nasdasdasd\n![รูปภาพ](http://192.168.195.200:8010/storage/v1/object/public/documents_images/26/f0fc4a20-04b6-48de-ac64-d5d717109efd_image_1.png)\n\n```js\nconsole.log("kuay")\n```',
#  'id': 26,
#  'created_at': '2025-11-18T12:27:10.731584Z',
#  'last_updated': '2025-11-18T12:29:39.573217',
#  'updated_by': 'ff',
#  'created_by': 'ff',
#  'created_by_id': '3f6bfd84-177e-467c-a28a-557df83bea96',
#  'updated_by_id': '3f6bfd84-177e-467c-a28a-557df83bea96'}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
